# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.DataFrame(pd.read_csv("moodbloom.csv"))
df["date"]=df["date"].apply(lambda x: 
                pd.to_datetime(x[2:]))
month_map = {
    1:"January",
    2:"February",
    3:"March",
    4:"April",
    5:"May",
    6:"June",
    7:"July",
    8:"August",
    9:"September",
    10:"October",
    11:"November",
    12:"December"
}
weekday_map = {
    0:"Monday", 1:"Tuesday", 2:"Wednesday",
    3:"Thursday", 4:"Friday", 5:"Saturday",
    6:"Sunday"
}
df["month"] = df["date"].dt.month.apply(lambda x: month_map[x])
#df["day"] = df["date"].dt.day
#df["weekday"] = df["date"].dt.day_of_week.apply(lambda x: weekday_map[x]) 
df=df.set_index("date")
df.head()
# Out:
#             workout  sleep  water   food   walk  meditation  screentime  \
# date
# 2025-09-11     True   True  False  False  False       False       False
# 2025-09-12    False  False  False  False  False       False       False
# 2025-09-14    False  False  False  False  False       False       False
# 2025-09-16     True  False  False   True  False       False        True
# 2025-09-21     True   True  False   True   True       False        True
#
#             gratitude  connect  nature   song  creative      month
# date
# 2025-09-11       True     True    True   True      True  September
# 2025-09-12      False    False   False  False     False  September
# 2025-09-14      False    False   False  False     False  September
# 2025-09-16      False    False   False   True      True  September
# 2025-09-21       True     True    True   True      True  September

# %%
user_month="September"
df = pd.DataFrame(pd.read_csv("moodbloom.csv"))
df["date"]=df["date"].apply(lambda x: 
                pd.to_datetime(x[2:]))
df["month"] = df["date"].dt.month.apply(lambda x: month_map[x])
df=df[df["month"]==user_month].drop(columns="month")
dates=pd.date_range(df["date"][0], df["date"][len(df)-1])

# %%
df
# Out:
#         date  workout  sleep  water   food   walk  meditation  screentime  \
# 0 2025-09-11     True   True  False  False  False       False       False
# 1 2025-09-12    False  False  False  False  False       False       False
# 2 2025-09-14    False  False  False  False  False       False       False
# 3 2025-09-16     True  False  False   True  False       False        True
# 4 2025-09-21     True   True  False   True   True       False        True
#
#    gratitude  connect  nature   song  creative
# 0       True     True    True   True      True
# 1      False    False   False  False     False
# 2      False    False   False  False     False
# 3      False    False   False   True      True
# 4       True     True    True   True      True

# %%
falses=[False for var in range(len(df.columns)-1)]
for date in dates:
    print(date)
# Out:
# 2025-09-11 00:00:00
# 2025-09-12 00:00:00
# 2025-09-13 00:00:00
# 2025-09-14 00:00:00
# 2025-09-15 00:00:00
# 2025-09-16 00:00:00
# 2025-09-17 00:00:00
# 2025-09-18 00:00:00
# 2025-09-19 00:00:00
# 2025-09-20 00:00:00
# 2025-09-21 00:00:00

# %%
for date in df["date"]:
    print(date)
# Out:
# 2025-09-11 00:00:00
# 2025-09-12 00:00:00
# 2025-09-14 00:00:00
# 2025-09-16 00:00:00
# 2025-09-21 00:00:00

# %%
falses=[False for var in range(len(df.columns)-1)]
for date in dates:
    if date not in list(df["date"]):
        df.loc[len(df)]=[date]+falses

# %%
#df_copy["completion"]=df_copy.sum(axis=1)/12
#df_copy = df_copy.reset_index()

# %%
falses=[False for var in range(len(df.columns)-1)]
for date in dates:
    if date not in list(df["date"]):
        df.loc[len(df)]=[date]+falses
df=df.set_index("date")
df["completion"]=df.sum(axis=1)/df.shape[1]
df=df.reset_index()
df.head()
# Out:
#         date  workout  sleep  water   food   walk  meditation  screentime  \
# 0 2025-09-11     True   True  False  False  False       False       False
# 1 2025-09-12    False  False  False  False  False       False       False
# 2 2025-09-14    False  False  False  False  False       False       False
# 3 2025-09-16     True  False  False   True  False       False        True
# 4 2025-09-21     True   True  False   True   True       False        True
#
#    gratitude  connect  nature   song  creative  completion
# 0       True     True    True   True      True    0.583333
# 1      False    False   False  False     False    0.000000
# 2      False    False   False  False     False    0.000000
# 3      False    False   False   True      True    0.416667
# 4       True     True    True   True      True    0.833333

# %%
falses=[False for var in range(len(df.columns)-1)]
for date in dates:
    if date not in list(df["date"]):
        df.loc[len(df)]=[date]+falses
df=df.set_index("date")
df["completion"]=df.sum(axis=1)/df.shape[1]
df=df.reset_index()
df["week"] = df["date"].dt.day.apply(lambda x: "Week 1" if x in range(1,8) else
                                              ("Week 2" if x in range(8,15) else (
                                                  "Week 3" if x in range(15,22) else 
                                                  "Week 4"))) 
days_order=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
df["weekday"]=pd.Categorical(df["date"].dt.day_of_week.apply(lambda x: weekday_map[x]),categories=days_order,ordered=True)
df
# Out:
#          date  workout  sleep  water   food   walk  meditation  screentime  \
# 0  2025-09-11     True   True  False  False  False       False       False
# 1  2025-09-12    False  False  False  False  False       False       False
# 2  2025-09-14    False  False  False  False  False       False       False
# 3  2025-09-16     True  False  False   True  False       False        True
# 4  2025-09-21     True   True  False   True   True       False        True
# 5  2025-09-13    False  False  False  False  False       False       False
# 6  2025-09-15    False  False  False  False  False       False       False
# 7  2025-09-17    False  False  False  False  False       False       False
# 8  2025-09-18    False  False  False  False  False       False       False
# 9  2025-09-19    False  False  False  False  False       False       False
# 10 2025-09-20    False  False  False  False  False       False       False
#
# ...

# %%
calendar_data=df.pivot_table(columns="weekday",
                    values="completion",index="week")
# Out:
# C:\Users\tanis\AppData\Local\Temp\ipykernel_9184\173779920.py:1: FutureWarning:
#
# The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior

# %%
calendar_data
# Out:
# weekday  Monday   Tuesday  Wednesday  Thursday  Friday  Saturday    Sunday
# week
# Week 2      NaN       NaN        NaN  0.583333     0.0       0.0  0.000000
# Week 3      0.0  0.416667        0.0  0.000000     0.0       0.0  0.833333

# %%
# Assuming `calendar_data` is your pivot table
fig = px.imshow(
    calendar_data,
    labels=dict(x="Weekday", y="Week", color="Completion"),
    color_continuous_scale='YlGnBu',  # or your Moodicle palette
    aspect="auto"
)

fig.update_layout(
    title="September Habit Completion",
    xaxis_title="Day of Week",
    yaxis_title="Week",
    height=500, width=800
)

fig.show()
